# %%
import numpy as np
import matplotlib.pyplot as plt

import jax
from functools import partial
import jax.numpy as jnp

plt.rcParams['figure.figsize'] = [12, 8] # PDF 

import time
from tqdm import tqdm

from Dynamics import logistic_map, henon_map
from Kernels import ext_kernel
from Losses import rho_comp

from Optimizer import main_flow, main_sos
from DataManager import get_curr_data, sample_points
from utils import get_predict_func, gen_traj, predict_series, get_pred_funcs, set_seed, hausdorff_distance, save_res, load_res
from notebook_utils import do_test, get_thetas, print_stats, get_latex_test, get_latex_train

jax.config.update("jax_enable_x64", True)


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# flow: 0.0089 roughly for lr=0.3

  
# SOS
# # found min 0.005399735226533475
# # sample min 0.00537916092405899

# found min 0.008960731937232014
# sample min 0.009312023253550628

# found min 0.004603925506856399
# sample min 0.004938442815559774

# %%
a = 1.4
b = 0.3
x = -0.75
y = -0.3

x_vec_0 = [x, y]



traj_train = jnp.array(gen_traj(henon_map(a, b), x_vec_0, 1000))

X_train = traj_train[:-1]
Y_train = traj_train[1:]

# %%
flow_para = {
    "lr": 0.3,
    "num_steps": 200
}

sos_para = {
    "N_samples": 200,
    "N_steps": 100,
    "lmbda": 1e-5,
    "eps": 1e-6,
    "sig": 1e-1
}

start_seed = 0

num_theta = 10
thetas_flow, losses_flow, thetas_sos, losses_sos = get_thetas(X_train, Y_train, start_seed, flow_para, sos_para, num_theta)
# Out:
# 100%|██████████| 200/200 [00:54<00:00,  3.67it/s]
# flow min 0.020509187956245234
# 100%|██████████| 200/200 [00:09<00:00, 20.95it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.31it/s]
# found min 0.004220483296829669
# sample min 0.004215350512243421
# 100%|██████████| 200/200 [00:48<00:00,  4.14it/s]
# flow min 0.00225882931564525
# 100%|██████████| 200/200 [00:08<00:00, 22.75it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.14it/s]
# found min 0.0006014254325416024
# sample min 0.0006027670766830528
# 100%|██████████| 200/200 [00:51<00:00,  3.89it/s]
# flow min 0.04985674629128023
# 100%|██████████| 200/200 [00:10<00:00, 19.37it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.65it/s]
# found min 0.0041978117399656956
# sample min 0.004136673960208781
# 100%|██████████| 200/200 [00:49<00:00,  4.00it/s]
# flow min 0.0035536964722870934
# 100%|██████████| 200/200 [00:08<00:00, 22.90it/s]
# 100%|██████████| 100/100 [00:07<00:00, 13.58it/s]
# found min 0.0010953698063559392
# sample min 0.0011188081654183168
# 100%|██████████| 200/200 [00:58<00:00,  3.41it/s]
# flow min 0.0038841705438952268
# 100%|██████████| 200/200 [00:13<00:00, 14.62it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.82it/s]
# found min 0.0033129013297180654
# sample min 0.0033177344262182995
# 100%|██████████| 200/200 [00:52<00:00,  3.78it/s]
# flow min 0.006068022974396126
# 100%|██████████| 200/200 [00:09<00:00, 21.37it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.59it/s]
# found min 0.0015665462018834564
# sample min 0.0016439428498242759
# 100%|██████████| 200/200 [00:50<00:00,  3.94it/s]
# flow min 0.019786262615432704
# 100%|██████████| 200/200 [00:09<00:00, 20.98it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.67it/s]
# found min 0.004876326042071222
# sample min 0.004886688436628095
# 100%|██████████| 200/200 [00:54<00:00,  3.66it/s]
# flow min 0.02305661978584328
# 100%|██████████| 200/200 [00:09<00:00, 20.81it/s]
# 100%|██████████| 100/100 [00:09<00:00, 11.07it/s]
# found min 0.00086343589459692
# sample min 0.000879735398371051
# 100%|██████████| 200/200 [01:00<00:00,  3.31it/s]
# flow min 0.016841232878086476
# 100%|██████████| 200/200 [00:13<00:00, 14.95it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.80it/s]
# found min 0.004787214393315087
# sample min 0.004941298105024194
# 100%|██████████| 200/200 [00:56<00:00,  3.51it/s]
# flow min 0.008782256717813741
# 100%|██████████| 200/200 [00:11<00:00, 16.68it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.20it/s]
# found min 0.0007284585800637622
# sample min 0.0007300351279462269
# 100%|██████████| 200/200 [01:05<00:00,  3.07it/s]
# flow min 0.02193087013705286
# 100%|██████████| 200/200 [00:15<00:00, 13.04it/s]
# 100%|██████████| 100/100 [00:11<00:00,  8.71it/s]
# found min 0.0020872663682353076
# sample min 0.0020888819885985788
# 100%|██████████| 200/200 [01:13<00:00,  2.74it/s]
# flow min 0.011691553207407113
# 100%|██████████| 200/200 [00:16<00:00, 12.07it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.96it/s]
# found min 0.0009829382195412073
# sample min 0.0009815609830227112
# 100%|██████████| 200/200 [01:03<00:00,  3.13it/s]
# flow min 0.008670711899537609
# 100%|██████████| 200/200 [00:09<00:00, 21.49it/s]
# 100%|██████████| 100/100 [00:07<00:00, 12.76it/s]
# found min 0.007009728472932353
# sample min 0.007012602609675844
# 100%|██████████| 200/200 [00:56<00:00,  3.53it/s]
# flow min 0.004331244070174711
# 100%|██████████| 200/200 [00:12<00:00, 16.65it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.57it/s]
# found min 0.001560574607940457
# sample min 0.0015691047501588118
# 100%|██████████| 200/200 [00:56<00:00,  3.55it/s]
# flow min 0.01088228884889264
# 100%|██████████| 200/200 [00:11<00:00, 16.75it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.92it/s]
# found min 0.0056393237961913645
# sample min 0.00621982663409526
# 100%|██████████| 200/200 [01:02<00:00,  3.20it/s]
# flow min 0.007494824706442804
# 100%|██████████| 200/200 [00:12<00:00, 16.02it/s]
# 100%|██████████| 100/100 [00:08<00:00, 11.43it/s]
# found min 0.0008941024396414976
# sample min 0.0011258462542459435
# 100%|██████████| 200/200 [00:57<00:00,  3.49it/s]
# flow min 0.033175756865629125
# 100%|██████████| 200/200 [00:13<00:00, 15.37it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.91it/s]
# found min 0.005157098853302178
# sample min 0.005101602955305817
# 100%|██████████| 200/200 [00:52<00:00,  3.78it/s]
# flow min 0.02194006767611889
# 100%|██████████| 200/200 [00:10<00:00, 19.71it/s]
# 100%|██████████| 100/100 [00:09<00:00, 10.51it/s]
# found min 0.002306320976639409
# sample min 0.002296990937211807
# 100%|██████████| 200/200 [00:57<00:00,  3.46it/s]
# flow min 0.0049412913507344
# 100%|██████████| 200/200 [00:13<00:00, 15.23it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.47it/s]
# found min 0.003131870974979578
# sample min 0.0031303548855876606
# 100%|██████████| 200/200 [01:00<00:00,  3.31it/s]
# flow min 0.019523798134032266
# 100%|██████████| 200/200 [00:13<00:00, 15.26it/s]
# 100%|██████████| 100/100 [00:10<00:00,  9.14it/s]
# found min 0.0007285871433015956
# sample min 0.0007268677524664424

# %%
theta_res = {
    "thetas_flow": thetas_flow,
    "losses_flow": losses_flow,
    "thetas_sos": thetas_sos,
    "losses_sos": losses_sos
}

save_res("Henon", theta_res)

# %% [markdown]
# # Testing

# %%
a = 1.4
b = 0.3

x_vec_0_test = jnp.array([0.5, 0.])

traj_test = jnp.array(gen_traj(henon_map(a, b), x_vec_0_test, 1000))

# %%
res = load_res("Henon")

# %%
# HD_losses_flow, deviate_steps_flow, mse_losses_flow = do_test(res['thetas_flow'], x_vec_0_test, traj_test, X_train, Y_train)
# HD_losses_sos, deviate_steps_sos, mse_losses_sos = do_test(res['thetas_sos'], x_vec_0_test, traj_test, X_train, Y_train)


HD_losses_flow_train, deviate_steps_flow_train, mse_losses_flow_train = do_test(res['thetas_flow'], x_vec_0, traj_train, X_train, Y_train)
HD_losses_sos_train, deviate_steps_sos_train, mse_losses_sos_train = do_test(res['thetas_sos'], x_vec_0, traj_train, X_train, Y_train)
# Out:
# 100%|██████████| 1000/1000 [00:35<00:00, 27.98it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.68it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.21it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.77it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.37it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.98it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.33it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.84it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.16it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.75it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.12it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.80it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.51it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.92it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.33it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.08it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.52it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.96it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.44it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.07it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.54it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.92it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.31it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.89it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.41it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.08it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.40it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.02it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.49it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 30.05it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.35it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.77it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.04it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.82it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.25it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.73it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.04it/s]
# 100%|██████████| 1000/1000 [00:33<00:00, 29.88it/s]
# 100%|██████████| 1000/1000 [00:35<00:00, 28.33it/s]
# 100%|██████████| 1000/1000 [00:32<00:00, 30.60it/s]

# %%
test_flow_res = {
    "HD_losses_flow": HD_losses_flow,
    "deviate_steps_flow": deviate_steps_flow,
    "mse_losses_flow": mse_losses_flow
}

test_sos_res = {
    "HD_losses_sos": HD_losses_sos,
    "deviate_steps_sos": deviate_steps_sos,
    "mse_losses_sos": mse_losses_sos
}

save_res("Henon", test_flow_res)
save_res("Henon", test_sos_res)

# %%
test_train_flow_res = {
    "HD_losses_flow_train": HD_losses_flow_train,
    "deviate_steps_flow_train": deviate_steps_flow_train,
    "mse_losses_flow_train": mse_losses_flow_train
}

test_train_sos_res = {
    "HD_losses_sos_train": HD_losses_sos_train,
    "deviate_steps_sos_train": deviate_steps_sos_train,
    "mse_losses_sos_train": mse_losses_sos_train
}

save_res("Henon", test_train_flow_res)
save_res("Henon", test_train_sos_res)

# %%
res = load_res("Henon")

# %%
print(get_latex_test(res))
# Out:
# MSE & $8.68 \ [6.40, 11.98] \times 10^{-5}$ & $1.03 \ [0.45, 2.58] \times 10^{-3}$ \\ HD & $4.03 \ [3.61, 5.37] \times 10^{-2}$ & $6.17 \ [4.08, 6.90] \times 10^{-2}$ \\ Deviation (0.1) & $9.00 \ [8.25, 9.00]$ & $6.00 \ [2.50, 8.00]$ \\ Deviation (0.25) & $1.00 \ [0.93, 1.00] \times 10^{1}$ & $7.00 \ [4.50, 9.00]$ \\

# %%
print(get_latex_train(res))
# Out:
# MSE & $2.43 \ [1.55, 4.14] \times 10^{-13}$ & $3.03 \ [1.85, 9.16] \times 10^{-14}$ \\ HD & $5.21 \ [3.74, 6.02] \times 10^{-2}$ & $4.28 \ [3.45, 6.62] \times 10^{-2}$ \\ Deviation (0.1) & $7.20 \ [6.50, 7.20] \times 10^{1}$ & $6.55 \ [5.75, 7.43] \times 10^{1}$ \\ Deviation (0.25) & $7.20 \ [6.60, 7.40] \times 10^{1}$ & $7.05 \ [6.25, 7.58] \times 10^{1}$ \\

# %%
print("Rho relative error")
for i_idx in range(res['losses_flow'].shape[1]):
    print("dim", i_idx)
    
    print("Flow")
    print_stats(res['losses_flow'][:, i_idx, -1])
    print()
    
    print("SOS")
    print_stats(res['losses_sos'][:, i_idx, -1])
    print()

# %%
print("Test Sets")

for k in ['HD_losses_flow', 'mse_losses_flow']:
    print(k)
    print_stats(res[k])
    print()
    
for k in ['HD_losses_sos', 'mse_losses_sos']:
    print(k)
    print_stats(res[k])
    print()
    
print("Deviate 0.1")
print("Flow")
print_stats(np.array(res['deviate_steps_flow'])[:, 0])

print("SOS")
print_stats(np.array(res['deviate_steps_sos'])[:, 0])
print()

print("Deviate 0.25")
print("Flow")
print_stats(np.array(res['deviate_steps_flow'])[:, 1])

print("SOS")
print_stats(np.array(res['deviate_steps_sos'])[:, 1])
print()

# %%
print("Train Sets")

for k in ['HD_losses_flow_train', 'mse_losses_flow_train']:
    print(k)
    print_stats(res[k])
    print()
    
for k in ['HD_losses_sos_train', 'mse_losses_sos_train']:
    print(k)
    print_stats(res[k])
    print()
    
print("Deviate 0.1")
print("Flow")
print_stats(np.array(res['deviate_steps_flow_train'])[:, 0])

print("SOS")
print_stats(np.array(res['deviate_steps_sos_train'])[:, 0])
print()

print("Deviate 0.25")
print("Flow")
print_stats(np.array(res['deviate_steps_flow_train'])[:, 1])

print("SOS")
print_stats(np.array(res['deviate_steps_sos_train'])[:, 1])
print()

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Y.idx 0

# %%
y_idx = 0
seed = 1


lr = 0.3
num_steps = 200

losses_flow_0, theta_star_flow_0 = main_flow(y_idx, ext_kernel, X_batch, y_batch, X_sub, y_sub, seed, lr, num_steps)



N=100 
lmbda=1e-5
eps=1e-6
sig=1e-1
losses_sos_0, theta_star_sos_0 = main_sos(y_idx, ext_kernel, X_batch, y_batch, X_sub, y_sub, seed, N, lmbda, eps, sig)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [02:32<00:00,  1.31it/s]
# flow min 0.0248946535473048
# 100%|█████████████████████████████████████████| 200/200 [00:40<00:00,  4.90it/s]
# 100%|█████████████████████████████████████████| 100/100 [00:26<00:00,  3.84it/s]
# found min 0.008892170640200203
# sample min 0.008862362668071722

# %%
plt.plot(losses_flow_0)
plt.plot(losses_sos_0)

# %%
plt.plot(losses_flow_0)
plt.plot(losses_sos_0)

# %% [markdown]
# ### Y.idx 1

# %%
found min 0.0010918840932231388
sample min 0.0010723259101861338

# %%
y_idx = 1

lr = 0.3
num_steps = 200
losses_flow_1, theta_star_flow_1 = main_flow(y_idx, ext_kernel, X_batch, y_batch, X_sub, y_sub, lr, num_steps)


seed=0
N=100 
lmbda=1e-4
eps=1e-6
sig=1e-1
losses_sos_1, theta_star_sos_1 = main_sos(y_idx, ext_kernel, X_batch, y_batch, X_sub, y_sub, seed, N, lmbda, eps, sig)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [02:03<00:00,  1.62it/s]
# flow min 0.006706600158051801
# 100%|█████████████████████████████████████████| 200/200 [00:34<00:00,  5.76it/s]
# 100%|█████████████████████████████████████████| 100/100 [00:22<00:00,  4.48it/s]
# found min 0.0014786979842228432
# sample min 0.001860817643250079

# %%
# y_idx = 1

# # losses_flow_1, theta_star_flow_1 = main_flow(y_idx)


# seed=0
# N=100 
# lmbda=1e-5
# eps=1e-6
# sig=1e-2
# losses_sos_1, theta_star_sos_1 = main_sos(y_idx, seed, N, lmbda, eps, sig)
# Out:
# 100%|█████████████████████████████████████████| 200/200 [00:37<00:00,  5.38it/s]
# 100%|█████████████████████████████████████████| 100/100 [00:22<00:00,  4.35it/s]
# found min 0.00146962071217549
# sample min 0.001860817643250079

# %%
plt.plot(losses_flow_1)
plt.plot(losses_sos_1)

# %%
plt.plot(losses_flow_1)
plt.plot(losses_sos_1)

# %% [markdown]
# ### Assessment

# %%
a = 1.4
b = 0.3

x_vec_0_test = jnp.array([0.5, 0.])
# x_vec_0_test = jnp.array([-0.75, -0.3])


traj_test = jnp.array(gen_traj(henon_map(a, b), x_vec_0_test, 1000))

X_test = traj_test[:-1]
Y_test = traj_test[1:]

# %%
# thetas_flow = thetajnp.array([theta_star_flow_0, theta_star_flow_1])
# thetas_sos = jnp.array([theta_star_sos_0, theta_star_sos_1])

pred_funcs_flow = get_pred_funcs(thetas_flow[0], ext_kernel, X_train, Y_train)
pred_funcs_sos = get_pred_funcs(thetas_sos[0], ext_kernel, X_train, Y_train)

# %% [markdown]
# #### Autoregressive

# %%
traj_preds_flow = predict_series(pred_funcs_flow, jnp.array(x_vec_0_test), 1000)
traj_preds_sos = predict_series(pred_funcs_sos, jnp.array(x_vec_0_test), 1000)
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [00:44<00:00, 22.30it/s]
# 100%|███████████████████████████████████████| 1000/1000 [00:42<00:00, 23.80it/s]

# %%
np.linalg.norm(traj_test - traj_preds_flow, axis=1)[:10]
# Out:
# array([0.        , 0.03546693, 0.06435805, 0.113728  , 0.23941726,
#        0.3589661 , 0.9237001 , 0.35754245, 0.8896387 , 0.69768209])

# %%
np.linalg.norm(traj_test - traj_preds_sos, axis=1)[:10]
# Out:
# array([0.        , 0.00061824, 0.00121909, 0.0020691 , 0.00469173,
#        0.00549087, 0.01696034, 0.01914274, 0.05028697, 0.09436751])

# %%
np.argmin(np.linalg.norm(traj_test - traj_preds_flow, axis=1) < 0.01)
# Out:
# 1

# %%
print("flow", hausdorff_distance(traj_test, traj_preds_flow))
print("sos", hausdorff_distance(traj_test, traj_preds_sos))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print("flow", hausdorff_distance(traj_test, traj_preds_flow))
#       2 print("sos", hausdorff_distance(traj_test, traj_preds_sos))
#
# NameError: name 'traj_preds_flow' is not defined

# %%
diff = np.linalg.norm((traj_test - traj_preds_flow), axis=1)

plt.plot(diff)
plt.show()

# %%
diff = np.linalg.norm((traj_test - traj_preds_sos), axis=1)

plt.plot(diff)
plt.show()

# %%
diff = np.linalg.norm((traj_test - traj_preds_flow), axis=1)

plt.plot(diff)
plt.show()

# %%
plt.scatter(traj_test[:, 0], traj_test[:, 1],  label='parametric curve')
plt.legend()

plt.show()

# %%
plt.scatter(traj_preds_flow[:, 0], traj_preds_flow[:, 1])
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(traj_preds_sos[:, 0], traj_preds_sos[:, 1], label='parametric curve')
plt.legend()

plt.show()
